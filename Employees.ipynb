# %%
import pandas as pd

# %%
df= pd.read_csv('employee_salary_dataset.csv')

# %%
df.head(5)
# Out:
#    EmployeeID        Name  Department  Experience_Years Education_Level  Age  \
# 0           1  Employee_1   Marketing                15          Master   53
# 1           2  Employee_2  Operations                 7        Bachelor   25
# 2           3  Employee_3          IT                12     High School   51
# 3           4  Employee_4  Operations                 8             PhD   44
# 4           5  Employee_5  Operations                15          Master   36
#
#    Gender       City  Monthly_Salary
# 0  Female      Delhi          111416
# 1  Female  Bangalore           95271
# 2  Female  Hyderabad           69064
# 3    Male      Delhi           95091
# 4  Female      Delhi          132450

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        50 non-null     int64
#  1   Name              50 non-null     object
#  2   Department        50 non-null     object
#  3   Experience_Years  50 non-null     int64
#  4   Education_Level   50 non-null     object
#  5   Age               50 non-null     int64
#  6   Gender            50 non-null     object
#  7   City              50 non-null     object
#  8   Monthly_Salary    50 non-null     int64
# dtypes: int64(4), object(5)
# memory usage: 3.6+ KB

# %%
df.describe()
# Out:
#        EmployeeID  Experience_Years        Age  Monthly_Salary
# count    50.00000         50.000000  50.000000         50.0000
# mean     25.50000          9.900000  39.760000      82288.8000
# std      14.57738          5.349995  11.539745      33521.4379
# min       1.00000          1.000000  22.000000      28420.0000
# 25%      13.25000          5.250000  28.250000      59424.0000
# 50%      25.50000         10.000000  43.500000      73890.5000
# 75%      37.75000         14.750000  49.000000     107219.0000
# max      50.00000         19.000000  57.000000     149123.0000

# %%
df_employees= df[['Name', 'Department' , 'Monthly_Salary']]
df_employees.sort_values(by='Monthly_Salary',ascending=False).head(5)
# Out:
#            Name  Department  Monthly_Salary
# 37  Employee_38  Operations          149123
# 10  Employee_11   Marketing          141381
# 33  Employee_34          HR          134616
# 24  Employee_25          HR          132455
# 4    Employee_5  Operations          132450

# %%
df_dept=df.groupby('Department')['Monthly_Salary'].mean().reset_index()
df_dept= df_dept.rename(columns={ 
    'Monthly_Salary': 'Average_Salary'})
print(df_dept)
# Out:
#    Department  Average_Salary
# 0     Finance    67261.900000
# 1          HR    82945.142857
# 2          IT    76520.500000
# 3   Marketing    96430.846154
# 4  Operations    84239.900000

# %%
import matplotlib.pyplot as plt
x=df['Experience_Years']
y=df['Monthly_Salary']
plt.scatter(x, y)
plt.xlabel('Experience Years')
plt.ylabel('Monthly Salary')
plt.title(' Scatter Plot')
plt.show()

# %%
df_best_salary_dept= df.groupby(['Name','Department'])[ 'Monthly_Salary'].max().reset_index(name='Monthly_Salary')

df_best_salary = df_best_salary_dept.loc[df_best_salary_dept.groupby('Department')['Monthly_Salary'].idxmax()]
print(df_best_salary)
# Out:
#            Name  Department  Monthly_Salary
# 20  Employee_28     Finance          118179
# 27  Employee_34          HR          134616
# 28  Employee_35          IT          130983
# 2   Employee_11   Marketing          141381
# 31  Employee_38  Operations          149123

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_dept.plot.bar(x='Department', y='Average_Salary',colormap='Paired')
plt.title('Average Salary by department')
plt.ylabel('Average Salary')
plt.show()
rot=0

# %%
correlation_value = df['Experience_Years'].corr(df['Monthly_Salary'])

print(f"The correlation is: {correlation_value}")
# Out:
# The correlation is: 0.07422086183046225

# %%
df_expnum=df_exp[['Experience_Years' , 'Monthly_Salary']]
print(df_expnum.corr())
# Out:
#                   Experience_Years  Monthly_Salary
# Experience_Years          1.000000        0.074221
# Monthly_Salary            0.074221        1.000000

# %%
# This creates one "box" for each department
df.boxplot(column='Monthly_Salary', by='Department')

import matplotlib.pyplot as plt
plt.title('Salary Distribution by Department')
plt.suptitle('') 
plt.show()

# %%
import matplotlib.pyplot as plt

df['Monthly_Salary'].plot(kind='hist', bins=10, edgecolor='white')

plt.title('Monthly Salary Distribution')
plt.xlabel('Salary Range')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='Monthly_Salary', by='Experience_Years')

import matplotlib.pyplot as plt
plt.title('Salary Distribution by Experience_Years')
plt.suptitle('') 
plt.show()
